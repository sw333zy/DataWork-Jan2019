# %%
import pandas as pd
import numpy as np

# %%
import seaborn; seaborn.set()
import matplotlib.pyplot as plt
import seaborn as sns

from datetime import datetime

# %matplotlib inline

# %%
location = "datasets/DC_Properties.csv"
df = pd.read_csv(location)
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (18,19,20,21,22,23,24,33,34,35,37,43,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#    Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 0           0       4          0      Warm Cool  Y        2.0      8      4
# 1           1       3          1      Warm Cool  Y        2.0     11      5
# 2           2       3          1  Hot Water Rad  Y        2.0      9      5
# 3           3       3          1  Hot Water Rad  Y        2.0      8      5
# 4           4       2          1      Warm Cool  Y        1.0     11      3
#
#       AYB  YR_RMDL   ...     LONGITUDE  ASSESSMENT_NBHD ASSESSMENT_SUBNBHD  \
# 0  1910.0   1988.0   ...    -77.040832       Old City 2   040 D Old City 2
# 1  1898.0   2007.0   ...    -77.040764       Old City 2   040 D Old City 2
# 2  1910.0   2009.0   ...    -77.040678       Old City 2   040 D Old City 2
# 3  1900.0   2003.0   ...    -77.040629       Old City 2   040 D Old City 2
# 4  1913.0   2012.0   ...    -77.039361       Old City 2   040 D Old City 2
#
# ...

# %%
df['SALEDATE'] = pd.to_datetime(df['SALEDATE'])

# %%
df.dtypes
# Out:
# Unnamed: 0                     int64
# BATHRM                         int64
# HF_BATHRM                      int64
# HEAT                          object
# AC                            object
# NUM_UNITS                    float64
# ROOMS                          int64
# BEDRM                          int64
# AYB                          float64
# YR_RMDL                      float64
# EYB                            int64
# STORIES                      float64
# SALEDATE              datetime64[ns]
# PRICE                        float64
# QUALIFIED                     object
# SALE_NUM                       int64
# GBA                          float64
# BLDG_NUM                       int64
# STYLE                         object
# STRUCT                        object
# GRADE                         object
# CNDTN                         object
# EXTWALL                       object
# ROOF                          object
# INTWALL                       object
# ...

# %%
df['SALEDATE'] = pd.to_datetime(df['SALEDATE'])

# %%
df['SALEDATE']
# Out:
# 0        2003-11-25
# 1        2000-08-17
# 2        2016-06-21
# 3        2006-07-12
# 4               NaT
# 5        2010-02-26
# 6        2011-05-02
# 7        2011-09-29
# 8        2018-05-03
# 9        2008-12-05
# 10              NaT
# 11       2009-03-12
# 12              NaT
# 13              NaT
# 14       2011-09-30
# 15              NaT
# 16       2010-11-04
# 17       2008-05-08
# 18       2016-08-18
# 19       2001-07-23
# 20       2016-01-12
# 21       2014-04-30
# 22       2006-01-09
# 23       2012-08-21
# 24       2012-07-25
# 25       1996-04-02
# 26              NaT
# 27       2005-04-06
# 28       2015-02-06
# 29       2013-12-11
#             ...
# 158927   2015-10-07
# 158928   2017-05-24
# 158929   2012-12-19
# 158930   2007-06-25
# 158931   2005-07-06
# 158932   2014-07-09
# 158933   2017-01-12
# 158934   2017-02-23
# 158935   2016-12-28
# 158936   2016-12-28
# 158937          NaT
# 158938   2015-03-02
# 158939   2016-09-30
# 158940   2008-06-04
# ...

# %%
df['SALEDATE'].dt.year
# Out:
# 0         2003.0
# 1         2000.0
# 2         2016.0
# 3         2006.0
# 4            NaN
# 5         2010.0
# 6         2011.0
# 7         2011.0
# 8         2018.0
# 9         2008.0
# 10           NaN
# 11        2009.0
# 12           NaN
# 13           NaN
# 14        2011.0
# 15           NaN
# 16        2010.0
# 17        2008.0
# 18        2016.0
# 19        2001.0
# 20        2016.0
# 21        2014.0
# 22        2006.0
# 23        2012.0
# 24        2012.0
# 25        1996.0
# 26           NaN
# 27        2005.0
# 28        2015.0
# 29        2013.0
#            ...
# 158927    2015.0
# 158928    2017.0
# 158929    2012.0
# 158930    2007.0
# 158931    2005.0
# 158932    2014.0
# 158933    2017.0
# 158934    2017.0
# 158935    2016.0
# 158936    2016.0
# 158937       NaN
# 158938    2015.0
# 158939    2016.0
# 158940    2008.0
# 158941       NaN
# 158942       NaN
# 158943    2004.0
# 158944    2016.0
# 158945    2006.0
# 158946    2015.0
# 158947    2008.0
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'BATHRM', 'HF_BATHRM', 'HEAT', 'AC', 'NUM_UNITS', 'ROOMS',
#        'BEDRM', 'AYB', 'YR_RMDL', 'EYB', 'STORIES', 'SALEDATE', 'PRICE',
#        'QUALIFIED', 'SALE_NUM', 'GBA', 'BLDG_NUM', 'STYLE', 'STRUCT', 'GRADE',
#        'CNDTN', 'EXTWALL', 'ROOF', 'INTWALL', 'KITCHENS', 'FIREPLACES',
#        'USECODE', 'LANDAREA', 'GIS_LAST_MOD_DTTM', 'SOURCE', 'CMPLX_NUM',
#        'LIVING_GBA', 'FULLADDRESS', 'CITY', 'STATE', 'ZIPCODE', 'NATIONALGRID',
#        'LATITUDE', 'LONGITUDE', 'ASSESSMENT_NBHD', 'ASSESSMENT_SUBNBHD',
#        'CENSUS_TRACT', 'CENSUS_BLOCK', 'WARD', 'SQUARE', 'X', 'Y', 'QUADRANT'],
#       dtype='object')

# %%
df2 = df[['BEDRM', 'BATHRM', 'QUADRANT', 'CNDTN', 'PRICE', 'SALEDATE']]

# %%
df2.columns
# Out:
# Index(['BEDRM', 'BATHRM', 'QUADRANT', 'CNDTN', 'PRICE', 'SALEDATE'], dtype='object')

# %%
df2.head()
# Out:
#    BEDRM  BATHRM QUADRANT      CNDTN      PRICE   SALEDATE
# 0      4       4       NW       Good  1095000.0 2003-11-25
# 1      5       3       NW       Good        NaN 2000-08-17
# 2      5       3       NW  Very Good  2100000.0 2016-06-21
# 3      5       3       NW       Good  1602000.0 2006-07-12
# 4      3       2       NW       Good        NaN        NaT

# %%
df2.dropna()
# Out:
#         BEDRM  BATHRM QUADRANT      CNDTN      PRICE   SALEDATE
# 0           4       4       NW       Good  1095000.0 2003-11-25
# 2           5       3       NW  Very Good  2100000.0 2016-06-21
# 3           5       3       NW       Good  1602000.0 2006-07-12
# 5           5       3       NW       Good  1950000.0 2010-02-26
# 7           4       3       NW    Average  1050000.0 2011-09-29
# 8           3       3       NW  Very Good  1430000.0 2018-05-03
# 14          3       3       NW  Very Good  1325000.0 2011-09-30
# 16          3       3       NW  Very Good  1240000.0 2010-11-04
# 19          3       3       NW       Good   592250.0 2001-07-23
# 20          5       3       NW  Very Good    33232.0 2016-01-12
# 22          3       1       NW       Good   907400.0 2006-01-09
# 23          3       2       NW  Very Good  1065000.0 2012-08-21
# 24          3       2       NW       Good  1100000.0 2012-07-25
# 25          4       1       NW       Good    20000.0 1996-04-02
# ...

# %%
sns.lmplot(x='BEDRM', y='PRICE', data=df2)
# Out:
# /anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df3 = df[['SQUARE', 'PRICE']]

# %%
sns.boxplot(data=df3)

# %%
df3.head()
# Out:
#   SQUARE      PRICE
# 0    152  1095000.0
# 1    152        NaN
# 2    152  2100000.0
# 3    152  1602000.0
# 4    152        NaN

# %%
df3.dropna()
# Out:
#        SQUARE      PRICE
# 0         152  1095000.0
# 2         152  2100000.0
# 3         152  1602000.0
# 5         152  1950000.0
# 7         152  1050000.0
# 8         152  1430000.0
# 14        152  1325000.0
# 16        152  1240000.0
# 19        152   592250.0
# 20        208    33232.0
# 22        208   907400.0
# 23        208  1065000.0
# 24        208  1100000.0
# 25        208    20000.0
# 27        208   703700.0
# 29        208  1210000.0
# 32        208   130500.0
# 37        208   339500.0
# 40        208  1050000.0
# 41        208  1550000.0
# 42        208  1599900.0
# 43        208  1700000.0
# 44        208  1700000.0
# 45        208   450000.0
# 46        208   846000.0
# 48        208   348500.0
# 50        208   849000.0
# 52        208  1312000.0
# 54        208   390000.0
# 55        208   772500.0
# ...       ...        ...
# 158918    475   839000.0
# 158919    475   915500.0
# 158920    475   880000.0
# 158921    475  1120000.0
# 158924    475   269000.0
# ...

# %%
sns.violinplot(x='QUADRANT', y='PRICE', data=df2)

# %%
#plt.subplots(figsize=(10,10))
#sns.swarmplot(x='QUADRANT', y='PRICE', data=df2)

# %%
sns.distplot(df2['BEDRM'])

# %%
df2.dropna()
# Out:
#         BEDRM  BATHRM QUADRANT      CNDTN      PRICE   SALEDATE
# 0           4       4       NW       Good  1095000.0 2003-11-25
# 2           5       3       NW  Very Good  2100000.0 2016-06-21
# 3           5       3       NW       Good  1602000.0 2006-07-12
# 5           5       3       NW       Good  1950000.0 2010-02-26
# 7           4       3       NW    Average  1050000.0 2011-09-29
# 8           3       3       NW  Very Good  1430000.0 2018-05-03
# 14          3       3       NW  Very Good  1325000.0 2011-09-30
# 16          3       3       NW  Very Good  1240000.0 2010-11-04
# 19          3       3       NW       Good   592250.0 2001-07-23
# 20          5       3       NW  Very Good    33232.0 2016-01-12
# 22          3       1       NW       Good   907400.0 2006-01-09
# 23          3       2       NW  Very Good  1065000.0 2012-08-21
# 24          3       2       NW       Good  1100000.0 2012-07-25
# 25          4       1       NW       Good    20000.0 1996-04-02
# ...

# %%
sns.distplot(df2['PRICE'])
# Out:
# /anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:28: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial)
# /anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:32: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims, initial)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-85fe4581ee5a> in <module>
# ----> 1 sns.distplot(df2['PRICE'])
#
# /anaconda3/lib/python3.7/site-packages/seaborn/distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     213     if hist:
#     214         if bins is None:
# --> 215             bins = min(_freedman_diaconis_bins(a), 50)
#     216         hist_kws.setdefault("alpha", 0.4)
# ...

# %%
df.PRICE = df.PRICE.astype(float)

# %%
pd.options.display.float_format = '{:,.0f}'.format
df2
# Out:
#         BEDRM  BATHRM QUADRANT      CNDTN     PRICE   SALEDATE
# 0           4       4       NW       Good 1,095,000 2003-11-25
# 1           5       3       NW       Good       nan 2000-08-17
# 2           5       3       NW  Very Good 2,100,000 2016-06-21
# 3           5       3       NW       Good 1,602,000 2006-07-12
# 4           3       2       NW       Good       nan        NaT
# 5           5       3       NW       Good 1,950,000 2010-02-26
# 6           2       1       NW    Average       nan 2011-05-02
# 7           4       3       NW    Average 1,050,000 2011-09-29
# 8           3       3       NW  Very Good 1,430,000 2018-05-03
# 9           2       1       NW    Average       nan 2008-12-05
# 10          5       3       NW       Fair       nan        NaT
# 11          6       5       NW    Average       nan 2009-03-12
# 12          5       2       NW    Average       nan        NaT
# 13          5       2       NW    Average       nan        NaT
# ...

# %%
df2.dropna()
# Out:
#         BEDRM  BATHRM QUADRANT      CNDTN     PRICE   SALEDATE
# 0           4       4       NW       Good 1,095,000 2003-11-25
# 2           5       3       NW  Very Good 2,100,000 2016-06-21
# 3           5       3       NW       Good 1,602,000 2006-07-12
# 5           5       3       NW       Good 1,950,000 2010-02-26
# 7           4       3       NW    Average 1,050,000 2011-09-29
# 8           3       3       NW  Very Good 1,430,000 2018-05-03
# 14          3       3       NW  Very Good 1,325,000 2011-09-30
# 16          3       3       NW  Very Good 1,240,000 2010-11-04
# 19          3       3       NW       Good   592,250 2001-07-23
# 20          5       3       NW  Very Good    33,232 2016-01-12
# 22          3       1       NW       Good   907,400 2006-01-09
# 23          3       2       NW  Very Good 1,065,000 2012-08-21
# 24          3       2       NW       Good 1,100,000 2012-07-25
# 25          4       1       NW       Good    20,000 1996-04-02
# ...

# %%
df2.dtypes
# Out:
# BEDRM                int64
# BATHRM               int64
# QUADRANT            object
# CNDTN               object
# PRICE              float64
# SALEDATE    datetime64[ns]
# dtype: object

# %%
sns.distplot(df2['PRICE'])
# Out:
# /anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# /anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:28: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial)
# /anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:32: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims, initial)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-85fe4581ee5a> in <module>
# ...

# %%
df2['PRICE'].fillna(0).astype(int)
# Out:
# 0         1095000
# 1               0
# 2         2100000
# 3         1602000
# 4               0
# 5         1950000
# 6               0
# 7         1050000
# 8         1430000
# 9               0
# 10              0
# 11              0
# 12              0
# 13              0
# 14        1325000
# 15              0
# 16        1240000
# 17              0
# 18              0
# 19         592250
# 20          33232
# 21              0
# 22         907400
# 23        1065000
# 24        1100000
# 25          20000
# 26              0
# 27         703700
# 28              0
# 29        1210000
#            ...
# 158927          0
# 158928     632400
# 158929     574000
# 158930     365000
# 158931     405000
# 158932     505000
# 158933     520000
# 158934     499900
# 158935     451000
# 158936     564900
# 158937          0
# 158938     660000
# 158939     380000
# 158940          0
# 158941          0
# 158942          0
# 158943     539000
# 158944     908500
# 158945     450000
# ...

# %%
df2.dtypes
# Out:
# BEDRM                int64
# BATHRM               int64
# QUADRANT            object
# CNDTN               object
# PRICE              float64
# SALEDATE    datetime64[ns]
# dtype: object

# %%
sns.distplot(df2['PRICE'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-85fe4581ee5a> in <module>
# ----> 1 sns.distplot(df2['PRICE'])
#
# /anaconda3/lib/python3.7/site-packages/seaborn/distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     213     if hist:
#     214         if bins is None:
# --> 215             bins = min(_freedman_diaconis_bins(a), 50)
#     216         hist_kws.setdefault("alpha", 0.4)
#     217         if LooseVersion(mpl.__version__) < LooseVersion("2.2"):
#
# /anaconda3/lib/python3.7/site-packages/seaborn/distributions.py in _freedman_diaconis_bins(a)
#      37         return int(np.sqrt(a.size))
#      38     else:
# ---> 39         return int(np.ceil((a.max() - a.min()) / h))
#      40
#      41
#
# ValueError: cannot convert float NaN to integer

# %%
sns.countplot(x='QUADRANT',
             data=df2,
             )

# %%
df2['PRICE'].dtypes
# Out:
# dtype('float64')

# %%
bins = [0, 100000, 200000, 300000, 400000, 500000, 1000000, 2500000, 5000000, 5000000]
group_names = ['1hun', '2hun', '3hun' '4hun', '5hun', '1mil','2.5mil', '5mil', 'BillGates']
df2['pricerange'] = pd.cut(df2['PRICE'], bins, labels=group_names)
df2.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-4f1f6966551a> in <module>
#       1 bins = [0, 100000, 200000, 300000, 400000, 500000, 1000000, 2500000, 5000000, 5000000]
#       2 group_names = ['1hun', '2hun', '3hun' '4hun', '5hun', '1mil','2.5mil', '5mil', 'BillGates']
# ----> 3 df2['pricerange'] = pd.cut(df2['PRICE'], bins, labels=group_names)
#       4 df2.head()
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/reshape/tile.py in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates)
#     232                               include_lowest=include_lowest,
#     233                               dtype=dtype,
# --> 234                               duplicates=duplicates)
#     235
#     236     return _postprocess_for_cut(fac, bins, retbins, x_is_series,
#
# ...
